# %% [markdown]
# <a href="https://colab.research.google.com/github/weberton/machine-learning-module2/blob/main/Regressao_Linear_Simples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

#importando a base de dados
dados = pd.read_excel("Sorvete.xlsx")
dados.head()
# Out:
#    Temperatura  Vendas_Sorvetes
# 0           26       268.125258
# 1           39       403.562400
# 2           34       339.279899
# 3           30       310.035329
# 4           27       273.616360

# %%
plt.scatter(dados['Temperatura'], dados['Vendas_Sorvetes'])
plt.xlabel('Temperatura (Celsius)')
plt.ylabel('Vendas de Sorvetes (milhares)')
plt.title('Relação entre Temperatura e Vendas de Soverte')
plt.show()

# %%
dados.corr()
# Out:
#                  Temperatura  Vendas_Sorvetes
# Temperatura         1.000000         0.985589
# Vendas_Sorvetes     0.985589         1.000000

# %%
x = dados[['Temperatura']]
y = dados[['Vendas_Sorvetes']]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=42)

print("Treinaremos com %d elementos e testaremos com %d elementos " % (len(x_train), len(x_test)))
# Out:
# Treinaremos com 80 elementos e testaremos com 20 elementos

# %%
modelo = LinearRegression()
modelo.fit(x_train, y_train)

previsoes = modelo.predict(x_test)

#Mean Squared Error Example - MSE formula = (1/n) * Σ(actual – forecast)2

erro_medio_quadratico = mean_squared_error(y_test, previsoes)

#It is the difference between the measured value and “true” value. For example, if a scale states 90 pounds but you know your true weight is 89 pounds, then the scale has an absolute error of 90 lbs – 89 lbs = 1 lbs.
erro_absoluto_medio = mean_absolute_error(y_test, previsoes)

r2_quadrado = r2_score(y_test, previsoes)

print(f'Erro médio quadrático: {erro_medio_quadratico}')
print(f'Erro absoluto médio: {erro_absoluto_medio}')
print(f'Rˆ2 (Coeficiente de determinacao): {r2_quadrado}')

plt.scatter(x_test, y_test, label='Real')
plt.scatter(x_test, previsoes, label='Previsto', color='red')
plt.xlabel('Temperaturs em Celsius')
plt.ylabel('Vendas de Sorvetes em milhares')
plt.title('Previsões do Modelo de Regressão Linear')
plt.legend()
plt.show()
# Out:
# Erro médio quadrático: 101.64524989805876
# Erro absoluto médio: 7.6809927436910055
# Rˆ2 (Coeficiente de determinacao): 0.9594169633031285
